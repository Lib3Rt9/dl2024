# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="yuHrs47HXxCqIgCsvfz1")
project = rf.workspace("renuka").project("anpr-pojnu")
version = project.version(6)
dataset = version.download("yolov9")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 10.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 10.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 9.6 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 10.2 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import cv2

# Load the image
image_path = "path/to/your/image.jpg"
image = cv2.imread(image_path)

# Display the image
cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Retrieve and print the label (replace with your actual label retrieval logic)
label = "License Plate"  # Example label
print(f"Label: {label}")
# Out:
# [ WARN:0@573.369] global loadsave.cpp:248 findDecoder imread_('path/to/your/image.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 8
#       5 image = cv2.imread(image_path)
#       7 # Display the image
# ----> 8 cv2.imshow("Image", image)
#       9 cv2.waitKey(0)
#      10 cv2.destroyAllWindows()
#
# error: OpenCV(4.8.0) /io/opencv/modules/highgui/src/window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
# !pip install gdown
# !gdown "1WceM5HuxdSiQBzMvhLdKZH88xohgCXaw"
# !unzip /shoe_sandal_boot.zip
# Out:
# ...
#   Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# ...
#   Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1WceM5HuxdSiQBzMvhLdKZH88xohgCXaw
# From (redirected): https://drive.google.com/uc?id=1WceM5HuxdSiQBzMvhLdKZH88xohgCXaw&confirm=t&uuid=6eba23e0-10bc-4408-b802-b19b347eea4e
# To: /storage/student14/phucpg/WORKSPACE/shoe_sandal_boot.zip
# 100%|██████████████████████████████████████| 49.3M/49.3M [00:06<00:00, 8.18MB/s]
# unzip:  cannot find or open /content/shoe_sandal_boot.zip, /content/shoe_sandal_boot.zip.zip or /content/shoe_sandal_boot.zip.ZIP.

# %%
# !unzip shoe_sandal_boot.zip
# Out:
# Archive:  shoe_sandal_boot.zip
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (10).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (100).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1000).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1001).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1002).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1003).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1004).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1005).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1006).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1007).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1008).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (1009).jpg
#   inflating: Shoe vs Sandal vs Boot Dataset/Boot/boot (101).jpg
# ...
